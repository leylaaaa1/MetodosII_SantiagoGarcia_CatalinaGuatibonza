# %% [markdown]
# # PUNTO 4 | INTEGRADOR SIMPLÉTICO

# %% [markdown]
# ![IMG_0552.jpg](attachment:IMG_0552.jpg)

# %%
import numpy as np

# %%
t = np.linspace(0,10,100)
h = 0.1

# %%
def CalcularJ(h):

    dxn1_dxn = 1
    dvn1_dxn = 0
    dvn1_dvn = 1
    dxn1_dvn = h
    
    J = dxn1_dxn * dvn1_dvn - dxn1_dvn * dvn1_dxn
    
    return J

Jacob = CalcularJ(h)

# %%
print("El Jacobiano es igual a:", Jacob)
# Out:
# El Jacobiano es igual a: 1.0
